# %% [markdown]
# # Baseline vs Fine-Tuned Evaluation: Qwen2.5-VL-7B
#
# **Goal**: Compare the base Qwen2.5-VL-7B-Instruct against the QLoRA fine-tuned model on the same held-out test set.
#
# | Metric | What It Measures |
# |--------|------------------|
# | **JSON Schema Compliance** | % of outputs that parse as valid JSON matching the target schema |
# | **Scene Type Accuracy** | Exact-match classification accuracy |
# | **ROUGE-L** | N-gram overlap between generated and reference captions |
# | **BERTScore** | Semantic similarity between generated and reference captions |
# | **Object Mention F1** | Precision/recall on predicted object types vs. ground truth |
#
# **Approach**: Load base model → run inference → compute metrics → load LoRA adapter → repeat → compare side by side.

# %%
# %%capture
# !pip install "transformers>=4.49" peft bitsandbytes qwen-vl-utils accelerate \
    rouge-score bert-score scikit-learn matplotlib

# %%
import json, time, sys
from pathlib import Path
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image
from google.colab import drive

# ── Mount Drive (needed before src/ imports) ────────────────────
drive.mount("/content/drive")

# ── Import shared modules ───────────────────────────────────────
DRIVE_PROJECT = Path("/content/drive/MyDrive/vlm-scene-analyser")
sys.path.insert(0, str(DRIVE_PROJECT))

from src.prompts import SYSTEM_PROMPT, USER_PROMPT
from src.inference import load_model, run_inference, extract_json, validate_schema
from src.evaluation import compute_all_metrics, extract_object_types

# ── Config ──────────────────────────────────────────────────────
QWEN_MODEL_ID = "Qwen/Qwen2.5-VL-7B-Instruct"
ADAPTER_PATH = DRIVE_PROJECT / "models" / "qwen_lora_v1"
TEST_SPLIT_PATH = ADAPTER_PATH / "test_split.jsonl"
IMAGE_DIR = Path("/content/images/nadir")

print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# PyTorch: 2.10.0+cu128
# CUDA: True
# GPU: NVIDIA L4

# %%
# ── Inference helper (loops over test set) ───────────────────
from qwen_vl_utils import process_vision_info


def run_test_inference(model, processor, test_ann):
    """Run inference on all test samples and return predictions list."""
    predictions = []
    for i, ann in enumerate(test_ann):
        raw = run_inference(model, processor, ann["image_path"])
        predictions.append({
            "image_file": ann["image_file"],
            "scene_type_gt": ann["scene_type"],
            "caption_gt": ann["caption"],
            "objects_gt": ann["objects"],
            "infrastructure_gt": ann["infrastructure"],
            "terrain_gt": ann["terrain"],
            "raw_prediction": raw,
        })
        print(f"[{i+1}/{len(test_ann)}] {ann['image_file'][:40]}... done")

    print(f"\nGenerated {len(predictions)} predictions.")
    return predictions


print("Utilities loaded (from src/).")
# Out:
# Utilities loaded (from src/).

# %%
# ── Load base model + test split ─────────────────────────────
import shutil

drive.mount("/content/drive")

# Copy images locally for faster I/O
if not IMAGE_DIR.exists():
    IMAGE_DIR.mkdir(parents=True, exist_ok=True)
    for f in (DRIVE_PROJECT / "images" / "nadir").glob("*.jpg"):
        shutil.copy2(f, IMAGE_DIR / f.name)

# Load base model (4-bit NF4, no adapter)
print(f"Loading {QWEN_MODEL_ID} (4-bit NF4)...")
base_model, processor = load_model(QWEN_MODEL_ID, quantize_4bit=True)
print("Base model loaded.")

# Load test split
test_ann = []
with open(TEST_SPLIT_PATH) as f:
    for line in f:
        ann = json.loads(line)
        ann["image_path"] = str(IMAGE_DIR / ann["image_file"])
        test_ann.append(ann)

print(f"Test set: {len(test_ann)} samples")
print(f"Scene types: {Counter(a['scene_type'] for a in test_ann)}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading Qwen/Qwen2.5-VL-7B-Instruct (4-bit NF4)...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/216 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Base model loaded.
# Test set: 17 samples
# Scene types: Counter({'residential_hdb': 4, 'commercial': 3, 'industrial': 2, 'mixed_use': 2, 'park_green': 2, 'airport': 1, 'port_terminal': 1, 'transport': 1, 'construction': 1})

# %% [markdown]
# ## Phase 1: Baseline (no LoRA)

# %%
# ── Baseline inference (cached) ──────────────────────────────
BASELINE_CACHE = DRIVE_PROJECT / "models" / "baseline_predictions.json"

if BASELINE_CACHE.exists():
    with open(BASELINE_CACHE) as f:
        baseline_predictions = json.load(f)

    # Validate cache matches current test split
    cached_files = [p["image_file"] for p in baseline_predictions]
    test_files = [a["image_file"] for a in test_ann]

    if cached_files != test_files:
        print("Test split changed — re-running baseline inference...")
        baseline_predictions = run_test_inference(base_model, processor, test_ann)
        with open(BASELINE_CACHE, "w") as f:
            json.dump(baseline_predictions, f, indent=2, ensure_ascii=False)
        print(f"Cache updated: {BASELINE_CACHE}")
    else:
        print(f"Loaded {len(baseline_predictions)} cached baseline predictions")
        # Update GT fields from current annotations (captions may have changed)
        for pred, ann in zip(baseline_predictions, test_ann):
            pred["caption_gt"] = ann["caption"]
            pred["scene_type_gt"] = ann["scene_type"]
            pred["objects_gt"] = ann["objects"]
            pred["infrastructure_gt"] = ann["infrastructure"]
            pred["terrain_gt"] = ann["terrain"]
else:
    print("No cached baseline found — running baseline inference...")
    baseline_predictions = run_test_inference(base_model, processor, test_ann)
    with open(BASELINE_CACHE, "w") as f:
        json.dump(baseline_predictions, f, indent=2, ensure_ascii=False)
    print(f"Saved to {BASELINE_CACHE}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Test split changed — re-running baseline inference...
# [1/17] nadir_airport_paya_lebar_ab_north_1.3687... done
# [2/17] nadir_industrial_woodlands_industrial_1.... done
# [3/17] nadir_commercial_changi_biz_park_1.335_1... done
# [4/17] nadir_hdb_bishan_1.3576_103.8472.jpg... done
# [5/17] nadir_port_keppel_terminal_1.263_103.832... done
# [6/17] nadir_mixed_west_coast_park_1.289_103.77... done
# [7/17] nadir_hdb_hougang_1.3707_103.8804.jpg... done
# [8/17] nadir_parks_gardens_by_bay_1.2816_103.86... done
# [9/17] nadir_parks_botanic_gardens_1.3138_103.8... done
# [10/17] nadir_hdb_queenstown_1.2939_103.8039.jpg... done
# [11/17] nadir_hdb_woodlands_hdb_1.4408_103.797.j... done
# [12/17] nadir_commercial_little_india_1.307_103.... done
# [13/17] nadir_commercial_kampong_glam_1.3017_103... done
# [14/17] nadir_transport_woodlands_ckpt_1.4491_10... done
# [15/17] nadir_mixed_marine_parade_vjc_1.3059_103... done
# [16/17] nadir_construction_mandai_dev_1.4043_103... done
# [17/17] nadir_industrial_amk_industrial_1.374_10... done
#
# Generated 17 predictions.
# Cache updated: /content/drive/MyDrive/vlm-scene-analyser/models/baseline_predictions.json

# %%
# ── Baseline metrics ─────────────────────────────────────────
print("Computing baseline metrics...\n")
baseline_metrics = compute_all_metrics(baseline_predictions, device=base_model.device)

print("=" * 50)
print("  BASELINE RESULTS")
print("=" * 50)
for k, v in baseline_metrics.items():
    if not k.startswith("_"):
        print(f"  {k:30s} {v}")
print("=" * 50)

# Schema compliance details
print("\nSchema compliance:")
for r in baseline_metrics["_details"]["schema_results"]:
    status = "OK" if r["valid"] else r["error"]
    print(f"  {r['image'][:45]:45s} {status}")

# Scene type confusion
print("\nScene type confusion:")
for gt, preds in sorted(baseline_metrics["_details"]["confusion"].items()):
    for predicted, count in sorted(preds.items(), key=lambda x: -x[1]):
        marker = "  +" if gt == predicted else "  x"
        print(f"  {gt:25s} -> {predicted:25s} {count}{marker}")
# Out:
# Computing baseline metrics...
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ==================================================
#   BASELINE RESULTS
# ==================================================
#   schema_compliance_pct          100.0
#   scene_type_accuracy_pct        52.9
#   rouge1_f1                      0.3248
#   rouge2_f1                      0.0399
#   rougeL_f1                      0.1928
#   bertscore_f1                   0.8749
#   object_mention_f1              0.3093
# ==================================================
#
# Schema compliance:
#   nadir_airport_paya_lebar_ab_north_1.3687_103. OK
#   nadir_industrial_woodlands_industrial_1.4519_ OK
#   nadir_commercial_changi_biz_park_1.335_103.96 OK
#   nadir_hdb_bishan_1.3576_103.8472.jpg          OK
#   nadir_port_keppel_terminal_1.263_103.832.jpg  OK
#   nadir_mixed_west_coast_park_1.289_103.7715.jp OK
#   nadir_hdb_hougang_1.3707_103.8804.jpg         OK
#   nadir_parks_gardens_by_bay_1.2816_103.8636.jp OK
#   nadir_parks_botanic_gardens_1.3138_103.8159.j OK
#   nadir_hdb_queenstown_1.2939_103.8039.jpg      OK
#   nadir_hdb_woodlands_hdb_1.4408_103.797.jpg    OK
#   nadir_commercial_little_india_1.307_103.852.j OK
#   nadir_commercial_kampong_glam_1.3017_103.8594 OK
#   nadir_transport_woodlands_ckpt_1.4491_103.77. OK
#   nadir_mixed_marine_parade_vjc_1.3059_103.9198 OK
#   nadir_construction_mandai_dev_1.4043_103.7858 OK
#   nadir_industrial_amk_industrial_1.374_103.863 OK
#
# Scene type confusion:
#   airport                   -> mixed_use                 1  x
#   commercial                -> residential_hdb           2  x
#   commercial                -> mixed_use                 1  x
#   construction              -> construction              1  +
#   industrial                -> industrial                2  +
#   mixed_use                 -> port_terminal             1  x
#   mixed_use                 -> mixed_use                 1  +
#   park_green                -> park_green                2  +
#   port_terminal             -> port_terminal             1  +
#   residential_hdb           -> residential_hdb           2  +
#   residential_hdb           -> mixed_use                 2  x
#   transport                 -> mixed_use                 1  x

# %% [markdown]
# ## Phase 2: Fine-tuned (with LoRA)

# %%
# ── Load LoRA adapter ────────────────────────────────────────
from peft import PeftModel

print(f"Loading LoRA adapter from {ADAPTER_PATH}...")
ft_model = PeftModel.from_pretrained(base_model, str(ADAPTER_PATH))
ft_model.eval()
print("Fine-tuned model loaded.")
# Out:
# Loading LoRA adapter from /content/drive/MyDrive/vlm-scene-analyser/models/qwen_lora_v1...
# Fine-tuned model loaded.

# %%
# ── Fine-tuned inference ─────────────────────────────────────
print("Running fine-tuned inference (with LoRA)...")
finetuned_predictions = run_test_inference(ft_model, processor, test_ann)
# Out:
# Running fine-tuned inference (with LoRA)...
# [1/17] nadir_airport_paya_lebar_ab_north_1.3687... done
# [2/17] nadir_industrial_woodlands_industrial_1.... done
# [3/17] nadir_commercial_changi_biz_park_1.335_1... done
# [4/17] nadir_hdb_bishan_1.3576_103.8472.jpg... done
# [5/17] nadir_port_keppel_terminal_1.263_103.832... done
# [6/17] nadir_mixed_west_coast_park_1.289_103.77... done
# [7/17] nadir_hdb_hougang_1.3707_103.8804.jpg... done
# [8/17] nadir_parks_gardens_by_bay_1.2816_103.86... done
# [9/17] nadir_parks_botanic_gardens_1.3138_103.8... done
# [10/17] nadir_hdb_queenstown_1.2939_103.8039.jpg... done
# [11/17] nadir_hdb_woodlands_hdb_1.4408_103.797.j... done
# [12/17] nadir_commercial_little_india_1.307_103.... done
# [13/17] nadir_commercial_kampong_glam_1.3017_103... done
# [14/17] nadir_transport_woodlands_ckpt_1.4491_10... done
# [15/17] nadir_mixed_marine_parade_vjc_1.3059_103... done
# [16/17] nadir_construction_mandai_dev_1.4043_103... done
# [17/17] nadir_industrial_amk_industrial_1.374_10... done
#
# Generated 17 predictions.

# %%
# ── Fine-tuned metrics ───────────────────────────────────────
print("Computing fine-tuned metrics...\n")
finetuned_metrics = compute_all_metrics(finetuned_predictions, device=ft_model.device)

print("=" * 50)
print("  FINE-TUNED RESULTS")
print("=" * 50)
for k, v in finetuned_metrics.items():
    if not k.startswith("_"):
        print(f"  {k:30s} {v}")
print("=" * 50)

# Schema compliance details
print("\nSchema compliance:")
for r in finetuned_metrics["_details"]["schema_results"]:
    status = "OK" if r["valid"] else r["error"]
    print(f"  {r['image'][:45]:45s} {status}")

# Scene type confusion
print("\nScene type confusion:")
for gt, preds in sorted(finetuned_metrics["_details"]["confusion"].items()):
    for predicted, count in sorted(preds.items(), key=lambda x: -x[1]):
        marker = "  +" if gt == predicted else "  x"
        print(f"  {gt:25s} -> {predicted:25s} {count}{marker}")
# Out:
# Computing fine-tuned metrics...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ==================================================
#   FINE-TUNED RESULTS
# ==================================================
#   schema_compliance_pct          100.0
#   scene_type_accuracy_pct        70.6
#   rouge1_f1                      0.536
#   rouge2_f1                      0.2679
#   rougeL_f1                      0.4018
#   bertscore_f1                   0.9165
#   object_mention_f1              0.4706
# ==================================================
#
# Schema compliance:
#   nadir_airport_paya_lebar_ab_north_1.3687_103. OK
#   nadir_industrial_woodlands_industrial_1.4519_ OK
#   nadir_commercial_changi_biz_park_1.335_103.96 OK
#   nadir_hdb_bishan_1.3576_103.8472.jpg          OK
#   nadir_port_keppel_terminal_1.263_103.832.jpg  OK
#   nadir_mixed_west_coast_park_1.289_103.7715.jp OK
#   nadir_hdb_hougang_1.3707_103.8804.jpg         OK
#   nadir_parks_gardens_by_bay_1.2816_103.8636.jp OK
#   nadir_parks_botanic_gardens_1.3138_103.8159.j OK
#   nadir_hdb_queenstown_1.2939_103.8039.jpg      OK
#   nadir_hdb_woodlands_hdb_1.4408_103.797.jpg    OK
#   nadir_commercial_little_india_1.307_103.852.j OK
#   nadir_commercial_kampong_glam_1.3017_103.8594 OK
#   nadir_transport_woodlands_ckpt_1.4491_103.77. OK
#   nadir_mixed_marine_parade_vjc_1.3059_103.9198 OK
#   nadir_construction_mandai_dev_1.4043_103.7858 OK
#   nadir_industrial_amk_industrial_1.374_103.863 OK
#
# Scene type confusion:
#   airport                   -> airport                   1  +
#   commercial                -> mixed_use                 1  x
#   commercial                -> commercial                1  +
#   commercial                -> residential_hdb           1  x
#   construction              -> construction              1  +
#   industrial                -> industrial                2  +
#   mixed_use                 -> port_terminal             1  x
#   mixed_use                 -> mixed_use                 1  +
#   park_green                -> park_green                2  +
#   port_terminal             -> port_terminal             1  +
#   residential_hdb           -> residential_hdb           3  +
#   residential_hdb           -> educational               1  x
#   transport                 -> port_terminal             1  x

# %% [markdown]
# ## Comparison

# %%
# ── Side-by-side qualitative comparison ───────────────────────
baseline_parsed = baseline_metrics["_details"]["parsed_preds"]
finetuned_parsed = finetuned_metrics["_details"]["parsed_preds"]

for i, (bp, fp, ann) in enumerate(zip(baseline_predictions, finetuned_predictions, test_ann)):
    b_obj = baseline_parsed[i] or {}
    f_obj = finetuned_parsed[i] or {}

    b_st = b_obj.get("scene_type", "<missing>")
    f_st = f_obj.get("scene_type", "<missing>")
    gt_st = ann["scene_type"]

    b_mark = "+" if b_st == gt_st else "x"
    f_mark = "+" if f_st == gt_st else "x"

    print("=" * 80)
    print(f"[{i+1}/{len(test_ann)}] {ann['image_file']}")
    print("-" * 80)

    print(f"  Scene Type:")
    print(f"    GT:         {gt_st}")
    print(f"    Baseline:   {b_st}  ({b_mark})")
    print(f"    Fine-tuned: {f_st}  ({f_mark})")

    print(f"\n  Caption:")
    print(f"    GT:         {ann['caption']}")
    print(f"    Baseline:   {b_obj.get('caption', '<missing>')}")
    print(f"    Fine-tuned: {f_obj.get('caption', '<missing>')}")

    gt_objs = sorted([f"{o['type']}({o['count']})" for o in ann.get("objects", [])])
    b_objs = sorted([f"{o['type']}({o['count']})" for o in b_obj.get("objects", [])])
    f_objs = sorted([f"{o['type']}({o['count']})" for o in f_obj.get("objects", [])])

    print(f"\n  Objects:")
    print(f"    GT:         {', '.join(gt_objs) or '(none)'}")
    print(f"    Baseline:   {', '.join(b_objs) or '(none)'}")
    print(f"    Fine-tuned: {', '.join(f_objs) or '(none)'}")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# [1/17] nadir_airport_paya_lebar_ab_north_1.3687_103.9161.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         airport
#     Baseline:   mixed_use  (x)
#     Fine-tuned: airport  (+)
#
#   Caption:
#     GT:         Airport viewed from above. A long runway with parallel taxiway runs diagonally across the frame with open grass fields alongside. Dense forest covers most of the surrounding area. Industrial buildings are visible along the periphery.
#     Baseline:   The image shows a mix of greenery and infrastructure. A large area of forested land occupies the center, surrounded by roads and a highway. To the left, there's a prominent MRT track, indicating a transportation hub. The bottom right corner features a cluster of buildings that could be part of a commercial or industrial estate. The terrain is predominantly urban with some green spaces.
#     Fine-tuned: Airport viewed from above. A single runway runs diagonally across the frame, with dense tropical forest and cleared land bordering one side. An expressway runs along one edge, with industrial buildings and warehouses visible nearby.
#
#   Objects:
#     GT:         aircraft(2)
#     Baseline:   aircraft(0), bus_interchange(0), cargo_ship(0), construction_crane(0), container_crane(0), hawker_centre(0), hdb_block(0), mrt_station(1), place_of_worship(0), school(0), shopping_mall(0), sports_facility(0), warehouse(0)
#     Fine-tuned: (none)
# ================================================================================
# [2/17] nadir_industrial_woodlands_industrial_1.4519_103.7985.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         industrial
#     Baseline:   industrial  (+)
#     Fine-tuned: industrial  (+)
#
#   Caption:
#     GT:         Industrial estate viewed from above. Warehouses and industrial buildings with grey, blue, and brown rooftops fill the frame, with some featuring rooftop solar panels. Open yards and patches of construction activity are scattered between the buildings. Cleared land and green fields are visible across the estate.
#     Baseline:   The image shows a large industrial area with numerous HDB blocks and warehouses spread across the landscape. There are also some green spaces and a few trees scattered throughout the area. A covered walkway can be seen connecting parts of the industrial complex. The terrain appears to be a mix of urban development and some open land areas.
#     Fine-tuned: Industrial estate viewed from above. Warehouses and factory buildings with grey, blue, and brown rooftops fill the frame in a tight grid of tree-lined streets. A few feature rooftop solar panels.
#
#   Objects:
#     GT:         construction_crane(2), warehouse(40)
#     Baseline:   covered_walkway(1), hdb_block(10), warehouse(20)
#     Fine-tuned: warehouse(40)
# ================================================================================
# [3/17] nadir_commercial_changi_biz_park_1.335_103.9653.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         commercial
#     Baseline:   mixed_use  (x)
#     Fine-tuned: mixed_use  (x)
#
#   Caption:
#     GT:         Business park viewed from above. Commercial and office buildings are arranged in clusters around curving landscaped roads, with dense tropical trees throughout. A curved building forming a near-complete ring sits at the centre. Several buildings have rooftop solar panel arrays, and elevated MRT tracks run along one edge.
#     Baseline:   The image shows a mix of urban development and green spaces in Singapore. A prominent circular structure resembling a traditional Chinese building is visible, surrounded by modern high-rise buildings and a network of roads. The area includes a hawker centre and a covered walkway connecting different parts of the complex. The presence of solar panels on rooftops indicates a focus on sustainable energy. The terrain is predominantly urban with some green areas, suggesting a balance between development and nature.
#     Fine-tuned: Mixed-use area viewed from above. A circular building with a rooftop pool and curved roofline sits at one edge, with several buildings featuring rooftop solar panels scattered across the frame. A large open green field occupies one corner, and mature trees fill the spaces between buildings.
#
#   Objects:
#     GT:         (none)
#     Baseline:   covered_walkway(1), hawker_centre(1), hdb_block(1)
#     Fine-tuned: (none)
# ================================================================================
# [4/17] nadir_hdb_bishan_1.3576_103.8472.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         residential_hdb
#     Baseline:   residential_hdb  (+)
#     Fine-tuned: residential_hdb  (+)
#
#   Caption:
#     GT:         Dense HDB estate viewed from above. Approximately 15 slab blocks with orange-red pitched roofs are arranged around a central open field. Multi-storey car parks sit among the blocks, and sports courts and a swimming pool are visible at a corner of the frame.
#     Baseline:   The image shows a cluster of HDB blocks with red-tiled roofs, surrounded by greenery and a central open space that appears to be a sports field. There are roads and pedestrian bridges connecting the blocks, indicating a well-developed residential area.
#     Fine-tuned: HDB estate viewed from above. Approximately 15 slab blocks with orange and grey rooftops are arranged around internal roads and a large green field. A multi-storey car park sits among the blocks, and sports courts are visible at one edge.
#
#   Objects:
#     GT:         hdb_block(15), sports_facility(1)
#     Baseline:   covered_walkway(2), hdb_block(10), sports_facility(1)
#     Fine-tuned: hdb_block(15)
# ================================================================================
# [5/17] nadir_port_keppel_terminal_1.263_103.832.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         port_terminal
#     Baseline:   port_terminal  (+)
#     Fine-tuned: port_terminal  (+)
#
#   Caption:
#     GT:         Container port viewed from above. A harbour channel separates a mainland container yard from an island terminal. A crane and cargo ship sit at the mainland berth. The island has colourful container stacks in dense rows, with cranes and cargo ships along the wharves. Trees and scattered buildings occupy the centre of the island.
#     Baseline:   The image shows a section of Singapore's port terminal, featuring numerous shipping containers arranged in neat rows along the waterfront. A large cargo ship is docked at one of the berths, surrounded by cranes for loading and unloading operations. The area is bordered by greenery and a small cluster of buildings, indicating a mix of industrial and possibly residential use. The water body adjacent to the port is part of the Singapore Strait.
#     Fine-tuned: Container port viewed from above. Container ships are berthed at wharves along one edge, with rows of containers stacked nearby. Cranes line the berths. A dense cluster of containers occupies another area, with a small park and buildings at its centre. An expressway runs along one edge, and a shipyard with storage tanks and cranes occupies another.
#
#   Objects:
#     GT:         cargo_ship(4), container_crane(10), warehouse(2)
#     Baseline:   cargo_ship(1), container(numerous), crane(multiple)
#     Fine-tuned: cargo_ship(2), container_crane(10), warehouse(2)
# ================================================================================
# [6/17] nadir_mixed_west_coast_park_1.289_103.7715.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         mixed_use
#     Baseline:   port_terminal  (x)
#     Fine-tuned: port_terminal  (x)
#
#   Caption:
#     GT:         Mixed-use area viewed from above. A container terminal with dense rows of colourful shipping containers and cranes occupies one side of the frame. Dense mature tropical trees surround a dark pond in a park at the centre. Landed houses with orange rooftops and condominium complexes fill the opposite side, separated from the park by an expressway.
#     Baseline:   The image shows a mix of industrial and green spaces in Singapore. On the left, there is a large container yard filled with shipping containers, indicative of a port terminal. In the center, a lush green park with a small pond is visible, surrounded by trees and pathways. To the right, residential HDB blocks can be seen, interspersed with some greenery. The area is bordered by roads and expressways, suggesting a well-connected urban environment.
#     Fine-tuned: Container terminal viewed from above. A dense row of stacked shipping containers lines one edge, with a large circular pond and mature trees occupying the centre. Residential buildings with orange-red rooftops and condominium blocks sit along the periphery, with an expressway running through the frame.
#
#   Objects:
#     GT:         condo(20), container_crane(4), landed_house(30), sports_facility(3)
#     Baseline:   container_crane(1), covered_walkway(1), hdb_block(2)
#     Fine-tuned: condo(5), container_crane(10), landed_house(10), warehouse(2)
# ================================================================================
# [7/17] nadir_hdb_hougang_1.3707_103.8804.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         residential_hdb
#     Baseline:   residential_hdb  (+)
#     Fine-tuned: residential_hdb  (+)
#
#   Caption:
#     GT:         Dense HDB estate viewed from above. Approximately 20 slab and point blocks with grey rooftops are arranged around a curving internal road, with several featuring rooftop solar panels. Orange-roofed covered walkways connect the blocks at ground level.
#     Baseline:   The image shows a dense residential area with HDB blocks arranged in a grid pattern. There are multiple roads curving through the area, some with visible traffic. Trees are interspersed between the buildings, providing greenery. A covered walkway can be seen connecting parts of the complex. The layout suggests a well-planned urban environment.
#     Fine-tuned: HDB estate viewed from above. Approximately 20 slab blocks with grey rooftops and rooftop solar panels are arranged in a tight cluster, with several featuring blue rooftops. A curved road runs through the centre, and mature trees line the roads.
#
#   Objects:
#     GT:         hdb_block(20)
#     Baseline:   covered_walkway(1), hdb_block(10)
#     Fine-tuned: hdb_block(20)
# ================================================================================
# [8/17] nadir_parks_gardens_by_bay_1.2816_103.8636.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         park_green
#     Baseline:   park_green  (+)
#     Fine-tuned: park_green  (+)
#
#   Caption:
#     GT:         Gardens by the Bay viewed from above. The Supertree Grove with its cluster of circular tree-shaped structures occupies the centre. Two large dome-shaped buildings with ribbed glass rooftops are visible nearby. A long narrow lake runs along one side, and landscaped gardens with winding pathways fill the remainder. Marina Bay Sands is partially visible at one corner, and a road interchange and cleared land sit at another.
#     Baseline:   The image shows a large green park with numerous trees and landscaped areas, including a central circular structure that resembles a garden or pavilion. Surrounding the park are roads and a body of water to the left. In the top right corner, there's a distinctive building with a unique architectural design, likely a landmark. The terrain is predominantly urban with some open spaces.
#     Fine-tuned: Botanic Gardens viewed from above. A large lake curves through the centre of the frame, with mature trees and landscaped lawns surrounding it. Circular buildings with distinctive rooftop structures sit along one edge of the lake. A major road runs along one boundary, and construction sites are visible at both edges.
#
#   Objects:
#     GT:         (none)
#     Baseline:   aircraft(0), bus_interchange(0), cargo_ship(0), construction_crane(0), container_crane(0), hawker_centre(0), hdb_block(0), mrt_station(0), place_of_worship(0), school(0), shopping_mall(0), sports_facility(0), warehouse(0)
#     Fine-tuned: (none)
# ================================================================================
# [9/17] nadir_parks_botanic_gardens_1.3138_103.8159.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         park_green
#     Baseline:   park_green  (+)
#     Fine-tuned: park_green  (+)
#
#   Caption:
#     GT:         Park viewed from above. Dense tropical canopy covers most of the frame, with a small lake and open lawns visible among the trees. Buildings with orange, white, and grey rooftops sit along winding pathways through the canopy. Landed houses with orange-red rooftops line the edges of the park, and a small construction site with exposed earth occupy one corner.
#     Baseline:   A lush green park occupies the center of the image, surrounded by dense tree cover and a few scattered buildings. The park features a large open area with a small pond and a central structure, possibly a pavilion or monument. Surrounding the park are residential HDB blocks and a mix of other structures, indicating a blend of urban development and green spaces.
#     Fine-tuned: Dense park viewed from above. A large lake and meandering paths sit at the centre, surrounded by mature tropical trees. Condominium blocks with orange-red rooftops line one edge, and HDB blocks with grey rooftops occupy another.
#
#   Objects:
#     GT:         construction_crane(1), landed_house(30)
#     Baseline:   covered_walkway(1), hdb_block(1)
#     Fine-tuned: condo(10), hdb_block(5)
# ================================================================================
# [10/17] nadir_hdb_queenstown_1.2939_103.8039.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         residential_hdb
#     Baseline:   mixed_use  (x)
#     Fine-tuned: educational  (x)
#
#   Caption:
#     GT:         HDB estate viewed from above. Approximately 15 slab blocks with grey rooftops are densely arranged around curving roads, with several featuring rooftop solar panels. Multi-storey car parks are visible within the estate, and dense tropical trees fill the spaces between blocks.
#     Baseline:   The image shows a large campus-like area surrounded by greenery and roads. The central structure appears to be a university or institutional building complex, featuring multiple interconnected buildings with flat roofs. There are several smaller hawker centres and covered walkways visible around the perimeter, indicating a mix of academic and community facilities. The surrounding area includes a mix of trees and open spaces, suggesting a blend of urban development and greenery.
#     Fine-tuned: University campus viewed from above. A large circular building with a central court and surrounding buildings with grey rooftops occupies the centre. Condominium blocks with rooftop solar panels and a sports court sit along one edge, with mature trees filling the spaces between.
#
#   Objects:
#     GT:         hdb_block(15)
#     Baseline:   covered_walkway(4), hawker_centre(2), hdb_block(0), mrt_station(0)
#     Fine-tuned: condo(4), sports_facility(1)
# ================================================================================
# [11/17] nadir_hdb_woodlands_hdb_1.4408_103.797.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         residential_hdb
#     Baseline:   mixed_use  (x)
#     Fine-tuned: residential_hdb  (+)
#
#   Caption:
#     GT:         HDB estate viewed from above. Approximately 20 point and slab blocks are arranged in clusters around a central open space with a sports court and a blue sheltered walkway. Multiple blocks feature rooftop solar panels. Dense tropical trees fill the spaces between blocks, and multi-storey car parks and a major road are visible at the periphery.
#     Baseline:   The image shows a large cluster of HDB blocks surrounded by greenery and roads. A covered walkway connects parts of the complex, and there's a visible MRT station nearby. The area appears to be part of a mixed-use development, integrating residential living with public transportation access.
#     Fine-tuned: HDB estate viewed from above. Approximately 20 slab blocks with grey rooftops and rooftop solar panels are arranged in a tight cluster, with mature trees filling the spaces between them. An elevated MRT track runs along one edge.
#
#   Objects:
#     GT:         hdb_block(20), sports_facility(1)
#     Baseline:   hdb_block(1), mrt_station(1)
#     Fine-tuned: hdb_block(20)
# ================================================================================
# [12/17] nadir_commercial_little_india_1.307_103.852.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         commercial
#     Baseline:   residential_hdb  (x)
#     Fine-tuned: commercial  (+)
#
#   Caption:
#     GT:         Shophouse district viewed from above. Dense rows of shophouses with orange terracotta rooftops fill most of the frame in a tight grid of narrow streets. A large building with blue roof and several commercial buildings sit among the shophouses. HDB blocks are visible at the edges.
#     Baseline:   The image shows a dense residential area dominated by HDB blocks, characterized by their uniform red-tiled roofs. The streets are well-defined and intersect at right angles, typical of Singapore's urban planning. A few green spaces are visible, providing contrast to the built environment. The presence of solar panels on some buildings suggests a focus on sustainable living.
#     Fine-tuned: Shophouse estate viewed from above. Approximately 20 shophouses with orange-red terracotta rooftops fill the frame in a tight grid pattern. A few feature rooftop solar panels. A church with a grey roof and blue rectangular pool sits among the shophouses.
#
#   Objects:
#     GT:         hdb_block(4), shophouse(80)
#     Baseline:   covered_walkway(2), hdb_block(10)
#     Fine-tuned: place_of_worship(1), shophouse(20)
# ================================================================================
# [13/17] nadir_commercial_kampong_glam_1.3017_103.8594.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         commercial
#     Baseline:   residential_hdb  (x)
#     Fine-tuned: residential_hdb  (x)
#
#   Caption:
#     GT:         Shophouse district viewed from above. Dense rows of shophouses with orange terracotta rooftops fill most of the frame in a tight grid of narrow streets. A mosque with a distinctive golden dome is visible among the shophouses. Commercial buildings border the shophouses along the edges, and a stretch of construction activity runs alongside one of the roads.
#     Baseline:   The image shows a dense cluster of HDB blocks with red-tiled roofs, surrounded by greenery and a few trees. A covered walkway can be seen connecting some buildings, and there's a MRT station visible in the background. The area appears to be part of a residential neighborhood.
#     Fine-tuned: Dense HDB estate viewed from above. Approximately 20 slab blocks with orange-red clay-tile roofs are arranged in a tight grid pattern. A multi-storey car park and a building with a green roof sit among the blocks, and mature trees line the streets.
#
#   Objects:
#     GT:         place_of_worship(1), shophouse(70)
#     Baseline:   hdb_block(1), mrt_station(1)
#     Fine-tuned: hdb_block(20)
# ================================================================================
# [14/17] nadir_transport_woodlands_ckpt_1.4491_103.77.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         transport
#     Baseline:   mixed_use  (x)
#     Fine-tuned: port_terminal  (x)
#
#   Caption:
#     GT:         Causeway viewed from above. Multi-lane roads fan out across a wide bridge over a body of water, with parallel white pipelines running alongside. An L-shaped jetty with moored boats sits along the shoreline, and dense vegetation occupies a nearby edge.
#     Baseline:   Aerial view of a coastal area featuring a multi-lane expressway curving along the water's edge. A covered walkway runs parallel to the highway, and a small hawker centre is visible nearby. The terrain transitions from urban development to green spaces and forested areas.
#     Fine-tuned: Marine terminal viewed from above. A curved expressway runs along one edge, with a large wharf extending into the sea across the frame. A cargo ship is berthed at the wharf, and a smaller vessel is moored nearby. A parking lot and buildings sit between the expressway and the wharf.
#
#   Objects:
#     GT:         (none)
#     Baseline:   covered_walkway(1), hawker_centre(1), hdb_block(0), park_connector(0)
#     Fine-tuned: cargo_ship(2), container_crane(10)
# ================================================================================
# [15/17] nadir_mixed_marine_parade_vjc_1.3059_103.9198.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         mixed_use
#     Baseline:   mixed_use  (+)
#     Fine-tuned: mixed_use  (+)
#
#   Caption:
#     GT:         Mixed-use area viewed from above. Several school compounds with orange-roofed buildings and sports fields occupy one side of the frame, with a prominent athletics track at the centre. Condominium blocks, HDB blocks, and landed houses with orange-red rooftops surround the schools. A canal runs through the estate, and a coastal park with dense trees and a beach strip border one edge.
#     Baseline:   The image shows a mix of urban and recreational facilities within a densely built area. A prominent sports field with a running track is visible, surrounded by greenery and trees. Nearby, there's a hawker centre with a covered walkway connecting different parts of the complex. The area is bordered by residential HDB blocks to the left and right, with a mix of other buildings interspersed throughout. The terrain includes a body of water along the coastline at the bottom right corner.
#     Fine-tuned: School campus viewed from above. Sports courts and a running track sit at the centre, with orange-roofed buildings arranged around them. A large building with a curved roof and a swimming pool is visible nearby. Residential blocks with orange-red rooftops and a multi-storey car park are spread across one edge, with a beach and coastline along another.
#
#   Objects:
#     GT:         condo(10), hdb_block(5), landed_house(25), school(3), sports_facility(3)
#     Baseline:   covered_walkway(1), hawker_centre(1), hdb_block(2), sports_facility(1)
#     Fine-tuned: condo(2), hdb_block(10), school(1)
# ================================================================================
# [16/17] nadir_construction_mandai_dev_1.4043_103.7858.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         construction
#     Baseline:   construction  (+)
#     Fine-tuned: construction  (+)
#
#   Caption:
#     GT:         Construction site viewed from above. Exposed earth, structural foundations, and circular building footprints are surrounded by dense tropical forest. Buildings with dark and grey-blue roofs sit among the surrounding forest. A wide multi-lane road runs diagonally across an edge, and a reservoir is partially visible nearby.
#     Baseline:   The image shows a construction site surrounded by dense greenery and a road network. There are multiple structures under development, indicating ongoing construction activities. The area is bordered by a body of water on one side and a forested area on another, suggesting a mix of urban development and natural environment.
#     Fine-tuned: Construction site viewed from above. A large area of exposed earth and construction materials occupies the centre, with partially completed buildings and cranes scattered across it. A road runs along one edge, and dense tropical forest borders another.
#
#   Objects:
#     GT:         construction_crane(4)
#     Baseline:   construction_crane(1), covered_walkway(1), hdb_block(2)
#     Fine-tuned: construction_crane(2)
# ================================================================================
# [17/17] nadir_industrial_amk_industrial_1.374_103.8633.jpg
# --------------------------------------------------------------------------------
#   Scene Type:
#     GT:         industrial
#     Baseline:   industrial  (+)
#     Fine-tuned: industrial  (+)
#
#   Caption:
#     GT:         Industrial estate viewed from above. Rows of long narrow buildings with grey rooftops occupy a portion of the frame, with larger industrial buildings filling the remainder. An open green field spans one edge, and construction activity with exposed earth is visible nearby. Some buildings feature rooftop solar panels.
#     Baseline:   The image shows a large industrial area with numerous HDB blocks on the left side and a mix of industrial buildings and warehouses on the right. There are green spaces interspersed throughout the area, indicating some parkland or open spaces. A road network is visible, with a prominent expressway running through the bottom left corner.
#     Fine-tuned: Industrial estate viewed from above. Warehouses and factory buildings with grey rooftops are arranged in rows across the frame, with some featuring rooftop solar panels. A major construction site with exposed earth occupies one section. Open fields and patches of greenery are visible between the buildings.
#
#   Objects:
#     GT:         construction_crane(1), warehouse(30)
#     Baseline:   bus_interchange(0), cargo_ship(0), construction_crane(0), container_crane(0), covered_walkway(0), hdb_block(1), mrt_station(0), place_of_worship(0), school(0), shopping_mall(0), sports_facility(0), warehouse(1)
#     Fine-tuned: construction_crane(1), warehouse(40)
#
# ================================================================================

# %%
# ── Side-by-side comparison table ─────────────────────────────

metric_keys = [
    ("schema_compliance_pct", "Schema Compliance (%)"),
    ("scene_type_accuracy_pct", "Scene Type Accuracy (%)"),
    ("rouge1_f1", "ROUGE-1 F1"),
    ("rouge2_f1", "ROUGE-2 F1"),
    ("rougeL_f1", "ROUGE-L F1"),
    ("bertscore_f1", "BERTScore F1"),
    ("object_mention_f1", "Object Mention F1"),
]

print("=" * 70)
print("  EVALUATION COMPARISON — Qwen2.5-VL-7B")
print("=" * 70)
print(f"  {'Metric':28s} {'Baseline':>10s} {'Fine-tuned':>12s} {'Delta':>10s}")
print("  " + "-" * 62)

for key, label in metric_keys:
    b = baseline_metrics[key]
    f = finetuned_metrics[key]
    delta = f - b
    sign = "+" if delta >= 0 else ""

    if "pct" in key:
        print(f"  {label:28s} {b:>9.1f}% {f:>11.1f}% {sign}{delta:>8.1f}%")
    else:
        print(f"  {label:28s} {b:>10.4f} {f:>12.4f} {sign}{delta:>9.4f}")

print("=" * 70)
# Out:
# ======================================================================
#   EVALUATION COMPARISON — Qwen2.5-VL-7B
# ======================================================================
#   Metric                         Baseline   Fine-tuned      Delta
#   --------------------------------------------------------------
#   Schema Compliance (%)            100.0%       100.0% +     0.0%
#   Scene Type Accuracy (%)           52.9%        70.6% +    17.7%
#   ROUGE-1 F1                       0.3248       0.5360 +   0.2112
#   ROUGE-2 F1                       0.0399       0.2679 +   0.2280
#   ROUGE-L F1                       0.1928       0.4018 +   0.2090
#   BERTScore F1                     0.8749       0.9165 +   0.0416
#   Object Mention F1                0.3093       0.4706 +   0.1613
# ======================================================================

# %%
# ── Comparison bar chart ──────────────────────────────────────

labels = [label for _, label in metric_keys]
baseline_vals = []
finetuned_vals = []

for key, _ in metric_keys:
    b = baseline_metrics[key]
    f = finetuned_metrics[key]
    # Normalise percentage metrics to 0-1 scale
    if "pct" in key:
        b, f = b / 100, f / 100
    baseline_vals.append(b)
    finetuned_vals.append(f)

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width/2, baseline_vals, width, label="Baseline", color="#5B9BD5")
bars2 = ax.bar(x + width/2, finetuned_vals, width, label="Fine-tuned", color="#70AD47")

ax.set_ylabel("Score (0-1)")
ax.set_title("Baseline vs Fine-tuned: Qwen2.5-VL-7B")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=35, ha="right")
ax.set_ylim(0, 1.05)
ax.legend()

# Value labels on bars
for bar in bars1:
    h = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, h + 0.01, f"{h:.2f}",
            ha="center", va="bottom", fontsize=8)
for bar in bars2:
    h = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, h + 0.01, f"{h:.2f}",
            ha="center", va="bottom", fontsize=8)

plt.tight_layout()
plt.savefig("baseline_vs_finetuned.png", dpi=150, bbox_inches="tight")
plt.show()

# ── Export combined results ───────────────────────────────────
combined_results = {
    "n_test": len(test_ann),
    "baseline": {k: v for k, v in baseline_metrics.items() if not k.startswith("_")},
    "finetuned": {k: v for k, v in finetuned_metrics.items() if not k.startswith("_")},
}

with open("evaluation_comparison.json", "w") as f:
    json.dump(combined_results, f, indent=2)
print("Results saved to evaluation_comparison.json")
# Out:
# Results saved to evaluation_comparison.json
